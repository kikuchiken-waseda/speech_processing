# %% [markdown]
# # pytorchaudioを試す

# %%
import torch
import torchaudio
import requests
import matplotlib.pyplot as plt

# %%
from python_dataset.utils import example_audio_file

# %% [markdown]
# ## 音声の確認

# %%
import IPython.display
IPython.display.Audio(example_audio_file())
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# ## waveform

# %%
waveform, sample_rate = torchaudio.load(example_audio_file())

plt.figure()
plt.plot(waveform.t().numpy())
